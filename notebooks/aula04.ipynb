# %%
pip install plotnine # pacote que permite usarmos o paccote Ggplot2 no Python
# Out:
# Requirement already satisfied: plotnine in /usr/local/python/3.10.4/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/codespace/.local/lib/python3.10/site-packages (from plotnine) (1.24.0)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from plotnine) (0.5.3)
# Requirement already satisfied: mizani>=0.8.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from plotnine) (0.8.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from plotnine) (0.13.5)
# Requirement already satisfied: pandas>=1.3.5 in /home/codespace/.local/lib/python3.10/site-packages (from plotnine) (1.5.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from plotnine) (3.6.2)
# Requirement already satisfied: scipy>=1.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from plotnine) (1.9.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (9.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (1.0.6)
# Requirement already satisfied: palettable in /usr/local/python/3.10.4/lib/python3.10/site-packages (from mizani>=0.8.1->plotnine) (3.3.0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.3.5->plotnine) (2022.7)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (3.6.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.19 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (1.24.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gapminder  # vamos usar os dados desse pacote
# Out:
# Requirement already satisfied: gapminder in /usr/local/python/3.10.4/lib/python3.10/site-packages (0.1)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.10/site-packages (from gapminder) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->gapminder) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->gapminder) (1.24.0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->gapminder) (2022.7)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->gapminder) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from plotnine import *
from plotnine.data import mpg
from plotnine.data import mtcars
from gapminder import gapminder
# %matplotlib inline
# magic command que ajuda a plotar gráficos no jupyter notebook
# https://towardsdatascience.com/top-8-magic-commands-in-jupyter-notebook-c1582e813560

# %% [markdown]
# A [documentacão](https://plotnine.readthedocs.io/en/stable/index.html) da biblioteca Plotnine é bastante interessante de se ler!

# %%
dados = pd.DataFrame({"var_x": list(range(4)),
                      "var_y": list(range(2,9,2)),
                      "var_grupo": ["a", "a","a", "b"]})
dados
# Out:
#    var_x  var_y var_grupo
# 0      0      2         a
# 1      1      4         a
# 2      2      6         a
# 3      3      8         b

# %%
#exemplo - o pacote é ggplot2; o ggplot é o comando !
ggplot(dados)
# Out:
# <ggplot: (8745761095801)>

# %%
#exemplo
ggplot(dados, aes(x = "var_x", y = "var_y"))
# Out:
# <ggplot: (8745815957306)>

# %%
#exemplo
(ggplot(dados, aes(x = "var_x", y = "var_y")) +
  geom_point()
)
# Out:
# <ggplot: (8745760968560)>

# %%
(ggplot(dados) +
  geom_point(aes(x = "var_x", y = "var_y",color = "var_grupo"))+
  facet_grid("~var_grupo"))
# Out:
# <ggplot: (8745760934282)>

# %%
(ggplot(dados, aes(x = "var_x", y = "var_y",color = "var_grupo")) +
  geom_point()+
  facet_grid("~var_grupo"))
# Out:
# <ggplot: (8745758719295)>

# %%
(ggplot(dados, aes(x = "var_x", y = "var_y",color = "var_grupo", label = "var_x")) +
  geom_label()+
  facet_grid("~var_grupo")) # label adiciona o valor do ponto x
# Out:
# <ggplot: (8745761096503)>

# %%
(ggplot(dados, aes(x = "var_x", y = "var_y",color = "var_grupo", label = "var_x")) +
  geom_label()+
  facet_grid("~var_grupo")+
  theme_dark()
 )
# Out:
# <ggplot: (8745758592004)>

# %% [markdown]
# ## Base de dados Cars93

# %%
cars93 = pd.read_csv("../dados/Cars93.csv")
cars93.describe()
# cars93.head(10)
cars93.columns
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Min.Price', 'Price', 'Max.Price',
#        'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain', 'Cylinders',
#        'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Man.trans.avail',
#        'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width',
#        'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight', 'Origin',
#        'Make'],
#       dtype='object')

# %% [markdown]
# ## Histograma

# %%
## Histograma
ggplot(cars93, aes(x = "Horsepower")) # precisamos especificar o tipo de gráfico
# Out:
# <ggplot: (8745758662386)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram())
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/plotnine/stats/stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 9'. Pick better value with 'binwidth'.
# <ggplot: (8745758458496)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(binwidth =10)) # espessura da coluna
# Out:
# <ggplot: (8745758379132)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(binwidth =10, color = "black", fill = "purple")
 )
# Out:
# <ggplot: (8737417950215)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(binwidth =10, color = "black", fill = "purple") +
 theme_bw()  # mudo o tema de fundo
 )
# Out:
# <ggplot: (8745758448565)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(binwidth =10, color = "black", fill = "purple") +
 theme_bw() +
 labs(x = "Nome eixo x",
      y = "Nome eiixo y",
      title = "Título",
      caption="Fonte de Dados")
 )
# Out:
# <ggplot: (8745758356988)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(bins =11, color = "black", fill = "purple") +
 theme_bw() +
 labs(x = "Horsepower",
      y = "Frequência",
      title = "Potência")
 )
# Out:
# <ggplot: (8745760947005)>

# %% [markdown]
# ## Gráfico de barras

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar()
 )
# Out:
# <ggplot: (8745758120849)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar(fill = "darkblue")
 )
# Out:
# <ggplot: (8737424984739)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar(fill = "darkblue") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro")
 )
# Out:
# <ggplot: (8737433008589)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar(fill = "darkblue") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_light()
 )
# Out:
# <ggplot: (8745758024614)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar(fill = "darkblue") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 facet_grid("~AirBags")
 )
# Out:
# <ggplot: (8737418760310)>

# %%
# como no gráfico acima o None aparece com uma coluna muito elevada, fiquei curioso para descrever a variável
# em termos de seu conteúdo
# farei uma descritiva

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) + # cor das colunas tipo de airbag
 geom_bar(position = "dodge", # coloca colunas lado a lado
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal()
 )
# Out:
# <ggplot: (8745758073853)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) +
 geom_bar(position = "dodge",
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 scale_fill_brewer(palette = "Purples",
                   direction = 1)
 )
# Out:
# <ggplot: (8745758140681)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) +
 geom_bar(position = "fill", # empilhado em 100%
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 scale_fill_brewer(palette = "Purples",
                   direction = 1)
 )
# Out:
# <ggplot: (8745758110138)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) +
 geom_bar(position = "stack", # empilhadado com base na freq. absoluta
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 scale_fill_brewer(palette = "Purples",
                   direction = 1)
 )
# Out:
# <ggplot: (8745758012083)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) +
 geom_bar(position = "stack", # empilhadado com base na freq. absoluta
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 scale_fill_brewer(palette = "Purples",
                   direction = 1) +
 coord_flip() # inverte eixos
 )
# Out:
# <ggplot: (8745758030401)>

# %% [markdown]
# ## Base de dados HairEyeColor

# %%
hair = pd.read_csv("../dados/HairEyeColor.csv")
hair.describe()
hair.head(10)
# Out:
#    Unnamed: 0   Hair    Eye   Sex  Freq
# 0           1  Black  Brown  Male    32
# 1           2  Brown  Brown  Male    53
# 2           3    Red  Brown  Male    10
# 3           4  Blond  Brown  Male     3
# 4           5  Black   Blue  Male    11
# 5           6  Brown   Blue  Male    50
# 6           7    Red   Blue  Male    10
# 7           8  Blond   Blue  Male    30
# 8           9  Black  Hazel  Male    10
# 9          10  Brown  Hazel  Male    25

# %%
# Transforma dado em categoria
hair['Genero'] = hair['Sex'].astype('category')
hair.head()
# Out:
#    Unnamed: 0   Hair    Eye   Sex  Freq Genero
# 0           1  Black  Brown  Male    32   Male
# 1           2  Brown  Brown  Male    53   Male
# 2           3    Red  Brown  Male    10   Male
# 3           4  Blond  Brown  Male     3   Male
# 4           5  Black   Blue  Male    11   Male

# %% [markdown]
# ## Box-plot

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  fill = "Sex")) +
 theme_minimal() +
 geom_boxplot()
)
# Out:
# <ggplot: (8745760961672)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot() +
 scale_x_discrete(labels = ["Homem", "Mulher"]) + # no R c()
 xlab("Sexo") +
 ylab("Frequencia") +
 scale_color_manual(values = ["darkblue", "red"]) # passamos uma lista do jeito do Python
)
# Out:
# <ggplot: (8745760925546)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot(outlier_colour = "black", # no R é outlier.colour
              outlier_shape = 8,
              outlier_size = 4) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) +
 xlab("Sexo") +
 ylab("Frequencia") +
 scale_color_manual(values = ["darkblue", "red"])
)
# Out:
# <ggplot: (8745758613769)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot(outlier_colour = "black", # no R é outlier.colour
              outlier_shape = 8,
              outlier_size = 4) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) +
 xlab("Sexo") +
 ylab("Frequencia") +
 scale_color_manual(values = ["darkblue", "red"])
)
# Out:
# <ggplot: (8745757856642)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot() +
 geom_dotplot(binaxis = 'y',
              stackdir = 'center',
              dotsize = 1,
              binwidth = 2) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) +
 xlab("Sexo") +
 ylab("Frequencia") +
 scale_color_manual(values = ["darkblue", "red"])
)
# Out:
# <ggplot: (8745758613559)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot(outlier_colour = "black", # no R é outlier.colour
              outlier_shape = 8,
              outlier_size = 4) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) + #cores padrao do ggplot2
 labs(title = "Boxplot",
      x = "Sexo",
      y = "Frequência")
)
# Out:
# <ggplot: (8745758457980)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  fill = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot(outlier_colour = "black", # no R é outlier.colour
              outlier_shape = 8,
              outlier_size = 4) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) + #cores padrao do ggplot2
 labs(title = "Boxplot",
      x = "Sexo",
      y = "Frequência") +
 scale_fill_manual(values = ["darkblue", "red"])
)
# Out:
# <ggplot: (8745757753311)>

# %%
# lembra que importamos no comeco da aula?
mtcars.describe()
mtcars.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # lembra que importamos no comeco da aula?
# ----> 2 mtcars.describe()
#       3 mtcars.head()
#
# NameError: name 'mtcars' is not defined

# %%
(ggplot(mtcars, aes(x="mpg", y="drat")) +
 geom_point()
)
# Out:
# <ggplot: (8745757635173)>

# %%
(ggplot(mtcars, aes(x="mpg", y="drat")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      caption = "Base de dados mtcars")
)
# Out:
# <ggplot: (8745756587876)>

# %%
(ggplot(mtcars, aes(x="mpg", y="drat", size="carb")) +  # note que as bolinhas serão associadas a 'carb'
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      caption = "Base de dados mtcars")
)
# Out:
# <ggplot: (8745757718444)>

# %%
(ggplot(mtcars, aes(x="mpg",  # lembrar de abrir parênteses p gerar o gráfico
                    y="drat",
                    size="carb",
                    colour="cyl")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars")
)
# Out:
# <ggplot: (8745757680601)>

# %%
(ggplot(mtcars, aes(x="mpg",
                    y="drat",
                    size="carb",
                    colour="cyl")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars") +
 geom_vline(xintercept=20, color="red") # no R é col="red"
)
# Out:
# <ggplot: (8745757690259)>

# %%
(ggplot(mtcars, aes(x="mpg",
                    y="drat",
                    size="carb",
                    colour="cyl")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars") +
 geom_hline(yintercept=4, color="red") # no R é col="red"
)
# Out:
# <ggplot: (8745757713357)>

# %%
(ggplot(mtcars, aes(x="mpg",
                    y="drat")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars") +
 geom_smooth(method = "lm", se = False, color = "red") # No R é FALSE
) # experimente o se = True para ver os intervalos de confiança - eu tentei na aula e não funcionou
# Out:
# <ggplot: (8745756513638)>

# %%
type(mpg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(mpg)
#
# NameError: name 'mpg' is not defined

# %%
(ggplot(mtcars, aes(x="mpg",
                    y="drat")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars") +
 #geom_smooth(method = "lm", se = True, color = "red") # No R é FALSE
 #geom_smooth(method = "lm", se = False, color = "red") # No R é FALSE
 geom_smooth(method = "lm", color = "red") # No R é FALSE
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:706, in PlainTextFormatter.__call__(self, obj)
#     699 stream = StringIO()
#     700 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     701     self.max_width, self.newline,
#     702     max_seq_length=self.max_seq_length,
#     703     singleton_pprinters=self.singleton_printers,
#     704     type_pprinters=self.type_printers,
#     705     deferred_pprinters=self.deferred_printers)
# --> 706 printer.pretty(obj)
#     707 printer.flush()
#     708 return stream.getvalue()
#
# File ~/.local/lib/python3.10/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/.local/lib/python3.10/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/ggplot.py:95, in ggplot.__repr__(self)
#      91 def __repr__(self):
#      92     """
#      93     Print/show the plot
#      94     """
# ---> 95     self.__str__()
#      96     return '<ggplot: (%d)>' % self.__hash__()
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/ggplot.py:86, in ggplot.__str__(self)
#      82 def __str__(self):
#      83     """
#      84     Print/show the plot
#      85     """
# ---> 86     self.draw(show=True)
#      88     # Return and empty string so that print(p) is "pretty"
#      89     return ''
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/ggplot.py:212, in ggplot.draw(self, return_ggplot, show)
#     209 self._resize_panels()
#     211 # Drawing
# --> 212 self._draw_layers()
#     213 self._draw_labels()
#     214 self._draw_breaks_and_labels()
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/ggplot.py:391, in ggplot._draw_layers(self)
#     387 """
#     388 Draw the main plot(s) onto the axes.
#     389 """
#     390 # Draw the geoms
# --> 391 self.layers.draw(self.layout, self.coordinates)
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/layer.py:63, in Layers.draw(self, layout, coord)
#      61 for i, l in enumerate(self, start=1):
#      62     l.zorder = i
# ---> 63     l.draw(layout, coord)
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/layer.py:414, in layer.draw(self, layout, coord)
#     411 self.data = self.geom.handle_na(self.data)
#     412 # At this point each layer must have the data
#     413 # that is created by the plot build process
# --> 414 self.geom.draw_layer(self.data, layout, coord, **params)
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/geoms/geom.py:237, in geom.draw_layer(self, data, layout, coord, **params)
#     235 panel_params = layout.panel_params[ploc]
#     236 ax = layout.axs[ploc]
# --> 237 self.draw_panel(pdata, panel_params, coord, ax, **params)
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/geoms/geom.py:272, in geom.draw_panel(self, data, panel_params, coord, ax, **params)
#     270 for _, gdata in data.groupby('group'):
#     271     gdata.reset_index(inplace=True, drop=True)
# --> 272     self.draw_group(gdata, panel_params, coord, ax, **params)
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/geoms/geom_smooth.py:55, in geom_smooth.draw_group(data, panel_params, coord, ax, **params)
#      53     params2 = params.copy()
#      54     params2['outline_type'] = 'full'
# ---> 55     geom_ribbon.draw_group(data2, panel_params,
#      56                            coord, ax, **params2)
#      58 data['alpha'] = 1
#      59 geom_line.draw_group(data, panel_params, coord, ax, **params)
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/geoms/geom_ribbon.py:79, in geom_ribbon.draw_group(data, panel_params, coord, ax, **params)
#      77 for _, udata in data.groupby(units, dropna=False):
#      78     udata.reset_index(inplace=True, drop=True)
# ---> 79     geom_ribbon.draw_unit(udata, panel_params, coord,
#      80                           ax, **params)
#
# File ~/.python/current/lib/python3.10/site-packages/plotnine/geoms/geom_ribbon.py:113, in geom_ribbon.draw_unit(data, panel_params, coord, ax, **params)
#     110     size = 0
#     111     color = 'none'
# --> 113 fill_between(
#     114     _x,
#     115     _min,
#     116     _max,
#     117     where=where,
#     118     interpolate=interpolate,
#     119     facecolor=fill,
#     120     edgecolor=color,
#     121     linewidth=size,
#     122     linestyle=data['linetype'].iloc[0],
#     123     zorder=params['zorder'],
#     124     rasterized=params['raster']
#     125 )
#     127 # Alpha does not affect the outlines
#     128 data['alpha'] = 1
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5367, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5365 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5366                  step=None, **kwargs):
# -> 5367     return self._fill_between_x_or_y(
#    5368         "x", x, y1, y2,
#    5369         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5272, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5268         kwargs["facecolor"] = \
#    5269             self._get_patches_for_fill.get_next_color()
#    5271 # Handle united data, such as dates
# -> 5272 ind, dep1, dep2 = map(
#    5273     ma.masked_invalid, self._process_unit_info(
#    5274         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5276 for name, array in [
#    5277         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5278     if array.ndim > 1:
#
# File ~/.local/lib/python3.10/site-packages/numpy/ma/core.py:2360, in masked_invalid(a, copy)
#    2332 def masked_invalid(a, copy=True):
#    2333     """
#    2334     Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358     """
# -> 2360     return masked_where(~(np.isfinite(getdata(a))), a, copy=copy)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
## Base de dados GapMinder

# %%
gapminder.describe()
gapminder.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
(ggplot(gapminder, aes("gdpPercap", "lifeExp")) +
 geom_point()
 )
# Out:
# <ggplot: (8745756440498)>

# %%
(ggplot(gapminder, aes(x ="gdpPercap",
                       y="lifeExp",
                       size= "pop")) +
 geom_point()
 )
# Out:
# <ggplot: (8745756600828)>

# %%
(ggplot(gapminder, aes(x ="gdpPercap",
                       y="lifeExp",
                       size= "pop",
                       colour = "country")) +
 geom_point(show_legend = False, alpha = 0.7)
 )
# Out:
# <ggplot: (8745757893131)>

# %%
(ggplot(gapminder, aes(x ="gdpPercap",
                       y="lifeExp",
                       size= "pop",
                       colour = "country")) +
 geom_point(show_legend = False, alpha = 0.7) +
 scale_x_log10() +   # tranformando a variável para esparramar melhor os dados no gráfico
 labs(x = "PIB per capita", y = "PIB per capita")
 )
# Out:
# <ggplot: (8745756536259)>

# %%
#vamos criar uma variável para guardar só os dados de 2007
gapminder_2007 = gapminder[gapminder["year"]== 2007]
gapminder_2007.head()
# Out:
#         country continent  year  lifeExp       pop     gdpPercap
# 11  Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23      Albania    Europe  2007   76.423   3600523   5937.029526
# 35      Algeria    Africa  2007   72.301  33333216   6223.367465
# 47       Angola    Africa  2007   42.731  12420476   4797.231267
# 59    Argentina  Americas  2007   75.320  40301927  12779.379640

# %%
(ggplot(gapminder_2007,
       aes(x = "gdpPercap", y = "lifeExp",
           color = "continent", size = "pop")) +
  geom_point() +
  scale_x_log10() +
  labs(title = "Health and wealth grow together",
       x = "Wealth (GDP per capita)",
       y = "Health (life expectancy)",
       color = "Continent",
       size = "Population",
       caption = "Source: The Gapminder Project - Data from 2007"))
# Out:
# <ggplot: (8745757645458)>

# %% [markdown]
# ## Customizando o seu gráfico
#
# Os elementos visuais do nosso gráficos não relacionados a representacão dos nossos dados podem ser customizados com comando theme(). [Neste artigo](https://cmdlinetips.com/2021/05/tips-to-customize-text-color-font-size-in-ggplot2-with-element_text/) vários elementos textuais são explorados. Neste [outro artigo](https://cmdlinetips.com/2021/06/ggplot2-theme-element_blank-tips/) o chamado element_blank é explorado (usamos ele para não plotar alguns elementos do gráfico). Já o artigo [deste link](https://cmdlinetips.com/2021/06/7-tips-to-customize-rectangle-elements-in-ggplot2-element_rect/) explora os elementos retangulares do gráfico como borda do painel do gráfico e por fim [este artigo](https://cmdlinetips.com/2021/05/tips-to-customize-lines-in-ggplot2-with-element_line/) mostra como customizar todas as linhas que não representam dados no nosso gráfico.
#
# O texto é voltado para o Ggplot2 no R mas podemos muito bem utilizar para o Plotnine do Python!

# %%
 p = (ggplot(gapminder_2007,
       aes(x = "gdpPercap", y = "lifeExp",
           color = "continent", size = "pop")) +
  geom_point() +
  scale_x_log10() +
  labs(title = "Health and wealth grow together",
       x = "Wealth (GDP per capita)",
       y = "Health (life expectancy)",
       color = "Continent",
       size = "Population",
       caption = "Source: The Gapminder Project - Data from 2007"))

p + theme(axis_title_x = element_text(size=16,
                                      color="purple",
                                      face="bold",
                                      angle=0))
# Out:
# <ggplot: (8745754487646)>

# %% [markdown]
# ## Salvando um gráfico

# %% [markdown]
# Para salvar, nós salvamos nosso gráfico em uma variável e utilizamos o comando *ggsave*
# Essa funcão aceita vários parâmetros para salvar o gráfico em vários formatos e tamanhos. Vale a pena olhar a sua [documentacao](https://plotnine.readthedocs.io/en/stable/generated/plotnine.ggplot.html)

# %%
graph = (ggplot(gapminder_2007,
       aes(x = "gdpPercap", y = "lifeExp",
           color = "continent", size = "pop")) +
  geom_point() +
  scale_x_log10() +
  labs(title = "Health and wealth grow together",
       x = "Wealth (GDP per capita)",
       y = "Health (life expectancy)",
       color = "Continent",
       size = "Population",
       caption = "Source: The Gapminder Project - Data from 2007"))

ggsave(plot = graph, filename = "gapminder_graph.png", path = "../img")
# Out:
# /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: ../img/gapminder_graph.png
